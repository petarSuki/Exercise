# %% [markdown]
# <a href="https://colab.research.google.com/github/petarSuki/Exercise/blob/main/Word_Frequency_Counter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install lxml

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import operator

# %%
def start(url):
  word_list = []
  source_code = requests.get(url).text
  soup = BeautifulSoup(source_code,features="html.parser")
  for post_text in soup.findAll('span',{'class':'container__headline-text'}):
    content = post_text.get_text(strip=True)
    words = content.lower().split()
    for each_word in words:
      print(each_word)
      word_list.append(each_word)
    clean_up_list(word_list)

# %%
start('https://edition.cnn.com/')
# Out:
# Streaming output truncated to the last 5000 lines.
# with
# dueling
# visits
# saturday
# da
# fani
# willis
# to
# face
# primary
# challenge
# amid
# trump
# case
# disqualification
# fight
# ‘mystery’
# starlike
# creature
# among
# 100
# potential
# new
# marine
# species
# discovered
# near
# new
# zealand
# teen
# science
# project
# suggests
# archimedes’
# invention
# was
# plausible
# quest
# to
# resurrect
# mammoths
# takes
# a
# step
# forward
# the
# truth
# about
# menopause
# and
# weight
# gain
# hit
# a
# fitness
# plateau
# here’s
# how
# to
# break
# out
# of
# it
# more
# than
# a
# third
# of
# teens
# say
# they
# spend
# too
# much
# time
# on
# their
# phones,
# new
# study
# finds
# apple
# backs
# down
# on
# eu
# ban
# for
# ‘fortnite’maker
# epic
# games
# house
# panel
# unanimously
# approves
# bill
# that
# could
# ban
# tiktok
# big
# changes
# for
# apple,
# google
# and
# other
# tech
# giants
# europe’s
# sweeping
# law
# goes
# into
# effect
# ...

# %%
def clean_up_list(word_list):
  clean_word_list = []
  for word in word_list:
    symbols = "!@#$%^&*()_+-=`~:\"'\.<>?|\}{[]}"
    for i in range (0, len(symbols)):
      word = word.replace(symbols[i], "")
    if len(word) > 0:
      print(word)
      clean_word_list.append(word)
  create_dictionary(clean_word_list)

# %%
start('https://edition.cnn.com/')
# Out:
# Streaming output truncated to the last 5000 lines.
# with
# dueling
# visits
# saturday
# da
# fani
# willis
# to
# face
# primary
# challenge
# amid
# trump
# case
# disqualification
# fight
# ‘mystery’
# starlike
# creature
# among
# 100
# potential
# new
# marine
# species
# discovered
# near
# new
# zealand
# teen
# science
# project
# suggests
# archimedes’
# invention
# was
# plausible
# quest
# to
# resurrect
# mammoths
# takes
# a
# step
# forward
# the
# truth
# about
# menopause
# and
# weight
# gain
# hit
# a
# fitness
# plateau
# here’s
# how
# to
# break
# out
# of
# it
# more
# than
# a
# third
# of
# teens
# say
# they
# spend
# too
# much
# time
# on
# their
# phones,
# new
# study
# finds
# apple
# backs
# down
# on
# eu
# ban
# for
# ‘fortnite’maker
# epic
# games
# house
# panel
# unanimously
# approves
# bill
# that
# could
# ban
# tiktok
# big
# changes
# for
# apple,
# google
# and
# other
# tech
# giants
# europe’s
# sweeping
# law
# goes
# into
# effect
# ...

# %%
def create_dictionary(clean_word_list):
  word_count = {}
  for word in clean_word_list:
    if word in word_count:
      word_count[word] += 1
    else:
      word_count[word] = 1
  for key, value in sorted(word_count.items(), key=operator.itemgetter(1)):
    print(key, value)

# %%
start('https://edition.cnn.com/')
# Out:
# Streaming output truncated to the last 5000 lines.
# grievances
# as
# gop
# leaders
# urge
# her
# to
# look
# forward
# biden
# signs
# key
# government
# funding
# bills
# into
# law
# averting
# shutdown
# bidentrump
# rematch
# kicks
# off
# in
# georgia
# with
# dueling
# visits
# saturday
# da
# fani
# willis
# to
# face
# primary
# challenge
# amid
# trump
# case
# disqualification
# fight
# ‘mystery’
# starlike
# creature
# among
# 100
# potential
# new
# marine
# species
# discovered
# near
# new
# zealand
# teen
# science
# project
# suggests
# archimedes’
# invention
# was
# plausible
# quest
# to
# resurrect
# mammoths
# takes
# a
# step
# forward
# the
# truth
# about
# menopause
# and
# weight
# gain
# hit
# a
# fitness
# plateau
# here’s
# how
# to
# break
# out
# of
# it
# more
# than
# a
# third
# of
# teens
# say
# they
# spend
# too
# much
# time
# on
# their
# phones,
# new
# study
# finds
# apple
# backs
# down
# on
# eu
# ban
# for
# ‘fortnite’maker
# epic
# ...
